# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb
print("Done")
# Out:
# Done

# %%
# This lets us see our created plots inside of our Jupyter Notebook
# %matplotlib inline
print("Done")
# Out:
# Done

# %%
x = np.linspace(0, 100, 11)
y = np.linspace(0, 200, 11)

# Create a new figure object
fig = plt.figure()

# Add our axes to the figure
ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title('Sample Graph')
ax.plot(x, y)

# %%
# Create a new figure object
fig = plt.figure()

# Add our axes to the figure
ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title('Sample Graph')
ax.plot([0, 2, 3], [2, 4, 0])

# %%
# Plot some sample financial data for the stock market
df = pd.read_csv('sample_data.csv', sep=',', parse_dates=True, index_col=0)

# sample the df from the csv data
df.head()

# plot the csv data
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Create a new figure object
fig = plt.figure()

# Add our axes to the figure
ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title('Sample Graph')
line_1 = ax.plot([10, 20, 30], [20, 40, 10], label='Line 1')
line_2 = ax.plot([10, 20, 30], [40, 10, 30], label='Line 2')
plt.legend()

# %%
# Example of a histogram
df1 = pd.read_csv('df1',index_col=0)
print(df1.head())

# A sample histogram of column A
df1['A'].hist()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# <AxesSubplot:>

# %%
# Sample area plot
df2 = pd.read_csv('df2')
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
# Sample Bar Plot
print(df2.head())
df2.plot.bar()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# <AxesSubplot:>

# %%
# Sample Scatter Plot
print(df1.head())
df1.plot.scatter(x='A',y='B')
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
# Add some color coding to scatter plot
print(df1.head())
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
# Sample Box Plot
print(df2.head())
df2.plot.box()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# <AxesSubplot:>
